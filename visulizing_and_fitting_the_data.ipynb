# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_s_1 = pd.read_csv('./pot_data_with_motor_s_1.csv')
df_s_5 = pd.read_csv('./pot_data_with_motor_s_5.csv')

# %%
print(df_s_1.info())
print(df_s_5.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4679 entries, 0 to 4678
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Timestamp           4679 non-null   object
#  1   Motor_Position      4679 non-null   int64
#  2   Potentiometer_Data  4679 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 109.8+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1093 entries, 0 to 1092
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Timestamp           1093 non-null   object
#  1   Motor_Position      1093 non-null   int64
#  2   Potentiometer_Data  1093 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 25.7+ KB
# None

# %%
print(df_s_1.describe())
print(df_s_5.describe())
# Out:
#        Motor_Position  Potentiometer_Data
# count     4679.000000         4679.000000
# mean      1540.270998          275.296003
# std       1011.540262          347.211227
# min          0.000000            0.000000
# 25%        659.000000           10.000000
# 50%       1527.000000          101.000000
# 75%       2418.000000          423.000000
# max       3298.000000         1023.000000
#        Motor_Position  Potentiometer_Data
# count     1093.000000         1093.000000
# mean      1400.805124          238.080512
# std       1070.389288          333.547055
# min          0.000000            0.000000
# 25%        354.000000            1.000000
# 50%       1368.000000           48.000000
# 75%       2337.000000          345.000000
# max       3316.000000         1023.000000

# %%
plt.figure(figsize=(10, 5))
plt.plot(np.array(df_s_1['Potentiometer_Data']), np.array(df_s_1['Motor_Position']), marker='o', linestyle='-')

# Customize the plot
plt.title('Motor Position vs Potentiometer Data with motor speed 1 Rev/min')
plt.xlabel('Potentiometer Data')
plt.ylabel('Motor Position')
plt.grid(True)

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(np.array(df_s_5['Potentiometer_Data']), np.array(df_s_5['Motor_Position']), marker='o', linestyle='-')

# Customize the plot
plt.title('Motor Position vs Potentiometer Data with motor speed 5 Rev/min')
plt.xlabel('Potentiometer Data')
plt.ylabel('Motor Position')
plt.grid(True)

# Show the plot
plt.show()

# %%
#making seprate individual data for every revolution  (1040 counts == 1 revolution)
filter_1 = df_s_1['Motor_Position']<=1040
filter_2 = (df_s_1['Motor_Position']>=1040) & (df_s_1['Motor_Position']<=2080)
filter_3 = (df_s_1['Motor_Position']>=2080) & (df_s_1['Motor_Position']<=3120)

# %%
df_s_1_1 = df_s_1[filter_1]
df_s_1_1.reset_index(drop=True)
# Out:
#                 Timestamp  Motor_Position  Potentiometer_Data
# 0     2024-07-24 18:48:24               0                   2
# 1     2024-07-24 18:48:24               0                   1
# 2     2024-07-24 18:48:24               0                   0
# 3     2024-07-24 18:48:24               0                   1
# 4     2024-07-24 18:48:24               0                   1
# ...                   ...             ...                 ...
# 1669  2024-07-24 18:49:20            1009                   0
# 1670  2024-07-24 18:49:20            1009                   0
# 1671  2024-07-24 18:49:20            1009                   0
# 1672  2024-07-24 18:49:20            1010                   0
# 1673  2024-07-24 18:49:20            1027                   0
#
# [1674 rows x 3 columns]

# %%
df_s_1_2 = df_s_1[filter_2]
df_s_1_2 = df_s_1_2.reset_index(drop=True)
df_s_1_2['Motor_Position'] = df_s_1_2['Motor_Position'] - 1040
print(df_s_1_2.head())
# Out:
#              Timestamp  Motor_Position  Potentiometer_Data
# 0  2024-07-24 18:49:20               5                   0
# 1  2024-07-24 18:49:20              17                   2
# 2  2024-07-24 18:49:20              17                   1
# 3  2024-07-24 18:49:21              17                   1
# 4  2024-07-24 18:49:21              17                   0

# %%
df_s_1_3 = df_s_1[filter_3]
df_s_1_3 = df_s_1_3.reset_index(drop=True)
df_s_1_3['Motor_Position'] = df_s_1_3['Motor_Position'] - 2080
print(df_s_1_3.head())
# Out:
#              Timestamp  Motor_Position  Potentiometer_Data
# 0  2024-07-24 18:50:17              11                   1
# 1  2024-07-24 18:50:18              26                   2
# 2  2024-07-24 18:50:18              27                   3
# 3  2024-07-24 18:50:18              27                   3
# 4  2024-07-24 18:50:18              27                   3

# %%
plt.figure(figsize=(10, 5))
plt.plot(np.array(df_s_1_1['Potentiometer_Data']), np.array(df_s_1_1['Motor_Position']), marker='o', linestyle='-')

# Customize the plot
plt.title('Motor Position vs Potentiometer Data with motor speed 1 Rev/min for 1st revolution')
plt.xlabel('Potentiometer Data')
plt.ylabel('Motor Position')
plt.grid(True)

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(np.array(df_s_1_2['Potentiometer_Data']), np.array(df_s_1_2['Motor_Position']), marker='o', linestyle='-')

# Customize the plot
plt.title('Motor Position vs Potentiometer Data with motor speed 1 Rev/min for 2nd revolution')
plt.xlabel('Potentiometer Data')
plt.ylabel('Motor Position')
plt.grid(True)

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(np.array(df_s_1_3['Potentiometer_Data']), np.array(df_s_1_3['Motor_Position']), marker='o', linestyle='-')

# Customize the plot
plt.title('Motor Position vs Potentiometer Data with motor speed 1 Rev/min for 3rd revolution')
plt.xlabel('Potentiometer Data')
plt.ylabel('Motor Position')
plt.grid(True)

# Show the plot
plt.show()

# %%
#Calculating the error i.e range where potentiometer shows 0 and 1023 for many values
data = df_s_1_1[:400]
data = data[data['Potentiometer_Data']==1]
lower_limit_0_val_for_rev_1 = data['Motor_Position'].max()
data = df_s_1_1[500:]
data1023 = data[data['Potentiometer_Data']==data['Potentiometer_Data'].max()]
lower_limit_1023_val_for_rev_1 = data1023['Motor_Position'].min()
print(f"\'motor\' starting position : {lower_limit_0_val_for_rev_1}   ending position : {lower_limit_1023_val_for_rev_1}")
print(f"\'potentiometer\' starting position : 1  ending position : {data1023['Potentiometer_Data'].min()}")
values_that_cannot_be_defined_1 = 1040-lower_limit_1023_val_for_rev_1+lower_limit_0_val_for_rev_1
print(values_that_cannot_be_defined_1)
# Out:
# 'motor' starting position : 0   ending position : 806
# 'potentiometer' starting position : 1  ending position : 1021
# 234

# %%
#Calculating the error i.e range where potentiometer shows 0 and 1023 for many values
data = df_s_1_2[:400]
data = data[data['Potentiometer_Data']==1]
lower_limit_0_val_for_rev_2 = data['Motor_Position'].max()
data = df_s_1_2[500:]
data1023 = data[data['Potentiometer_Data']==data['Potentiometer_Data'].max()]
lower_limit_1023_val_for_rev_2 = data1023['Motor_Position'].min()
print(f"\'motor\' starting position : {lower_limit_0_val_for_rev_2}   ending position : {lower_limit_1023_val_for_rev_2}")
print(f"\'potentiometer\' starting position : 1  ending position : {data1023['Potentiometer_Data'].min()}")
values_that_cannot_be_defined_2 = 1040-lower_limit_1023_val_for_rev_2+lower_limit_0_val_for_rev_2
print(values_that_cannot_be_defined_2)
# Out:
# 'motor' starting position : 18   ending position : 781
# 'potentiometer' starting position : 1  ending position : 1023
# 277

# %%
#Calculating the error i.e range where potentiometer shows 0 and 1023 for many values
data = df_s_1_3[:400]
data = data[data['Potentiometer_Data']==1]
lower_limit_0_val_for_rev_3 = data['Motor_Position'].max()
data = df_s_1_3[500:]
data1023 = data[data['Potentiometer_Data']==data['Potentiometer_Data'].max()]
lower_limit_1023_val_for_rev_3 = data1023['Motor_Position'].min()
print(f"\'motor\' starting position : {lower_limit_0_val_for_rev_3}   ending position : {lower_limit_1023_val_for_rev_3}")
print(f"\'potentiometer\' starting position : 1  ending position : {data1023['Potentiometer_Data'].min()}")
values_that_cannot_be_defined_3 = 1040-lower_limit_1023_val_for_rev_3+lower_limit_0_val_for_rev_3
print(values_that_cannot_be_defined_3)
# Out:
# 'motor' starting position : 27   ending position : 796
# 'potentiometer' starting position : 1  ending position : 1023
# 271

# %% [markdown]
# **Hence from above result we cannot determine the exact degree or placement of potentiometer for upto 265 different position. Which is around 92 degree**

# %% [markdown]
# **Again doing for another collected data.**

# %%
filter_1 = df_s_5['Motor_Position']<=1040
filter_2 = (df_s_5['Motor_Position']>=1040) & (df_s_5['Motor_Position']<=2080)
filter_3 = (df_s_5['Motor_Position']>=2080) & (df_s_5['Motor_Position']<=3120)

# %%
df_s_5_1 = df_s_5[filter_1]
df_s_5_1.reset_index(drop=True)
df_s_5_2 = df_s_5[filter_2]
df_s_5_2 = df_s_5_2.reset_index(drop=True)
df_s_5_2['Motor_Position'] = df_s_5_2['Motor_Position'] - 1040
print(df_s_5_2.head())
df_s_5_3 = df_s_5[filter_3]
df_s_5_3 = df_s_5_3.reset_index(drop=True)
df_s_5_3['Motor_Position'] = df_s_5_3['Motor_Position'] - 2080
print(df_s_5_3.head())
# Out:
#              Timestamp  Motor_Position  Potentiometer_Data
# 0  2024-07-24 18:46:58               0                   0
# 1  2024-07-24 18:46:58               0                   0
# 2  2024-07-24 18:46:58               6                   2
# 3  2024-07-24 18:46:58              23                   4
# 4  2024-07-24 18:46:58              33                   5
#              Timestamp  Motor_Position  Potentiometer_Data
# 0  2024-07-24 18:47:09              10                   2
# 1  2024-07-24 18:47:09              26                   4
# 2  2024-07-24 18:47:09              31                   4
# 3  2024-07-24 18:47:09              31                   4
# 4  2024-07-24 18:47:09              31                   4

# %%
plt.figure(figsize=(10, 5))
plt.plot(np.array(df_s_5_1['Potentiometer_Data']), np.array(df_s_5_1['Motor_Position']), marker='o', linestyle='-')

# Customize the plot
plt.title('Motor Position vs Potentiometer Data with motor speed 5 Rev/min for 1st revolution')
plt.xlabel('Potentiometer Data')
plt.ylabel('Motor Position')
plt.grid(True)

# Show the plot
plt.show()
plt.figure(figsize=(10, 5))
plt.plot(np.array(df_s_5_2['Potentiometer_Data']), np.array(df_s_5_2['Motor_Position']), marker='o', linestyle='-')

# Customize the plot
plt.title('Motor Position vs Potentiometer Data with motor speed 5 Rev/min for 2nd revolution')
plt.xlabel('Potentiometer Data')
plt.ylabel('Motor Position')
plt.grid(True)

# Show the plot
plt.show()
plt.figure(figsize=(10, 5))
plt.plot(np.array(df_s_5_3['Potentiometer_Data']), np.array(df_s_5_3['Motor_Position']), marker='o', linestyle='-')

# Customize the plot
plt.title('Motor Position vs Potentiometer Data with motor speed 5 Rev/min for 3rd revolution')
plt.xlabel('Potentiometer Data')
plt.ylabel('Motor Position')
plt.grid(True)

# Show the plot
plt.show()

# %%
#Calculating the error i.e range where potentiometer shows 0 and 1023 for many values
data = df_s_5_1[:int(df_s_5_1['Motor_Position'].count()/2)]
data = data[data['Potentiometer_Data']==data['Potentiometer_Data'].min()]
lower_limit_0_val_for_rev_1 = data['Motor_Position'].max()
data = df_s_5_1[int(df_s_5_1['Motor_Position'].count()/2):]
data1023 = data[data['Potentiometer_Data']==data['Potentiometer_Data'].max()]
lower_limit_1023_val_for_rev_1 = data1023['Motor_Position'].min()
print(f"\'motor\' starting position : {lower_limit_0_val_for_rev_1}   ending position : {lower_limit_1023_val_for_rev_1}")
print(f"\'potentiometer\' starting position : 1  ending position : {data1023['Potentiometer_Data'].min()}")
values_that_cannot_be_defined_1 = 1040-lower_limit_1023_val_for_rev_1+lower_limit_0_val_for_rev_1
print(values_that_cannot_be_defined_1)
#Calculating the error i.e range where potentiometer shows 0 and 1023 for many values
data = df_s_5_2[:int(df_s_5_2['Motor_Position'].count()/2)]
data = data[data['Potentiometer_Data']==0]
lower_limit_0_val_for_rev_2 = data['Motor_Position'].max()
data = df_s_5_2[int(df_s_5_2['Motor_Position'].count()/2):]
data1023 = data[data['Potentiometer_Data']==data['Potentiometer_Data'].max()]
lower_limit_1023_val_for_rev_2 = data1023['Motor_Position'].min()
print(f"\'motor\' starting position : {lower_limit_0_val_for_rev_2}   ending position : {lower_limit_1023_val_for_rev_2}")
print(f"\'potentiometer\' starting position : 0  ending position : {data1023['Potentiometer_Data'].min()}")
values_that_cannot_be_defined_2 = 1040-lower_limit_1023_val_for_rev_2+lower_limit_0_val_for_rev_2
print(values_that_cannot_be_defined_2)
#Calculating the error i.e range where potentiometer shows 0 and 1023 for many values
data = df_s_5_3[:int(df_s_5_3['Motor_Position'].count()/2)]
data = data[data['Potentiometer_Data']==2]
lower_limit_0_val_for_rev_3 = data['Motor_Position'].max()
data = df_s_5_3[int(df_s_5_3['Motor_Position'].count()/2):]
data1023 = data[data['Potentiometer_Data']==data['Potentiometer_Data'].max()]
lower_limit_1023_val_for_rev_3 = data1023['Motor_Position'].min()
print(f"\'motor\' starting position : {lower_limit_0_val_for_rev_3}   ending position : {lower_limit_1023_val_for_rev_3}")
print(f"\'potentiometer\' starting position : 2  ending position : {data1023['Potentiometer_Data'].min()}")
values_that_cannot_be_defined_3 = 1040-lower_limit_1023_val_for_rev_3+lower_limit_0_val_for_rev_3
print(values_that_cannot_be_defined_3)
# Out:
# 'motor' starting position : 0   ending position : 809
# 'potentiometer' starting position : 1  ending position : 1023
# 231
# 'motor' starting position : 0   ending position : 783
# 'potentiometer' starting position : 0  ending position : 1023
# 257
# 'motor' starting position : 10   ending position : 783
# 'potentiometer' starting position : 2  ending position : 1023
# 267

# %% [markdown]
# **For the speed 5 and 1 rev/min first calibration was done by human. But for the 2nd and 3rd revelotion, it was self corrected. for speed 1 rev/min we get for 2nd revolution<br>
# 'motor' starting position : 0   ending position : 806<br>
# 'potentiometer' starting position : 1  ending position : 1021 <br>
#  for 3rd revolution<br>
# 'motor' starting position : 18   ending position : 781<br>
# 'potentiometer' starting position : 1  ending position : 1023 <br>
# where as for speed 5 rev/min we get for 2nd revolution<br>
# 'motor' starting position : 0   ending position : 783<br>
# 'potentiometer' starting position : 0  ending position : 1023 <br>
# for 3rd revolution<br>
# 'motor' starting position : 10   ending position : 783<br>
# 'potentiometer' starting position : 2  ending position : 1023 .**

# %% [markdown]
# **As we have various reading for various data. To be on safe side, lets take data from position 0 - 750.**

# %%
filter = (df_s_1_2['Motor_Position']>=0) & (df_s_1_2['Motor_Position']<=750)
filtered_data = df_s_1_2[filter]

# %%
plt.figure(figsize=(10, 5))
plt.plot(np.array(filtered_data['Potentiometer_Data']), np.array(filtered_data['Motor_Position']), marker='o', linestyle='-')

# Customize the plot
plt.title('Motor Position vs Potentiometer Data with motor speed 1 Rev/min for filtered data')
plt.xlabel('Potentiometer Data')
plt.ylabel('Motor Position')
plt.grid(True)

# Show the plot
plt.show()

# %%
#adding a coloum for degree in data frame
filtered_data['Degree'] = (filtered_data['Motor_Position']/1040)*360
# Out:
# /tmp/ipykernel_24188/3961502964.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['Degree'] = (filtered_data['Motor_Position']/1040)*360

# %%
filtered_data.head()
# Out:
#              Timestamp  Motor_Position  Potentiometer_Data    Degree
# 0  2024-07-24 18:49:20               5                   0  1.730769
# 1  2024-07-24 18:49:20              17                   2  5.884615
# 2  2024-07-24 18:49:20              17                   1  5.884615
# 3  2024-07-24 18:49:21              17                   1  5.884615
# 4  2024-07-24 18:49:21              17                   0  5.884615

# %%
plt.figure(figsize=(10, 5))
plt.plot(np.array(filtered_data['Potentiometer_Data']), np.array(filtered_data['Degree']), marker='o', linestyle='-')

# Customize the plot
plt.title('Degree vs Potentiometer Data with motor speed 1 Rev/min for filtered data')
plt.xlabel('Potentiometer Data')
plt.ylabel('Degree')
plt.grid(True)

# Show the plot
plt.show()

# %%
#finding the best function to fit this data
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

X = filtered_data[['Potentiometer_Data']]
y = filtered_data[['Degree']]

poly = PolynomialFeatures(degree=5)
X_poly = poly.fit_transform(X)

# Create and fit the polynomial regression model
model = LinearRegression()
model.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
X_range = np.linspace(X.min(), X.max(), 100).reshape(-1, 1)
X_range_poly = poly.transform(X_range)
y_pred = model.predict(X_range_poly)


# Plot real data
plt.scatter(X, y, color='blue', label='Real data')

# Plot polynomial fit
plt.plot(X_range, y_pred, color='red', linestyle='--', label='Quadratic fit')

# Add labels and title
plt.xlabel('Feature')
plt.ylabel('Target')
plt.title('Quadratic Regression')
plt.legend()

# Show plot
plt.show()
# Out:
# /home/pawan/.local/lib/python3.10/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %%
X
# Out:
#      Potentiometer_Data
# 0                     0
# 1                     2
# 2                     1
# 3                     1
# 4                     0
# ..                  ...
# 986                 876
# 987                 877
# 988                 896
# 989                 923
# 990                 989
#
# [991 rows x 1 columns]

# %%
filtered_data.to_csv('filtered_data.csv', index=False)

# %%
filtered_data['Potentiometer_Datar2'] = np.sqrt(filtered_data['Potentiometer_Data'])
filtered_data['Potentiometer_Data2'] = filtered_data['Potentiometer_Data']**2
filtered_data['Potentiometer_Data3'] = filtered_data['Potentiometer_Data']**3
filtered_data['Potentiometer_Data4'] = filtered_data['Potentiometer_Data']**4
filtered_data['Potentiometer_Data5'] = filtered_data['Potentiometer_Data']**5
filtered_data['Potentiometer_Data6'] = filtered_data['Potentiometer_Data']**6
# Out:
# /tmp/ipykernel_24188/1858921086.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['Potentiometer_Datar2'] = np.sqrt(filtered_data['Potentiometer_Data'])
# /tmp/ipykernel_24188/1858921086.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['Potentiometer_Data2'] = filtered_data['Potentiometer_Data']**2
# /tmp/ipykernel_24188/1858921086.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
filtered_data.head()
# Out:
#              Timestamp  Motor_Position  Potentiometer_Data    Degree  \
# 0  2024-07-24 18:49:20               5                   0  1.730769
# 1  2024-07-24 18:49:20              17                   2  5.884615
# 2  2024-07-24 18:49:20              17                   1  5.884615
# 3  2024-07-24 18:49:21              17                   1  5.884615
# 4  2024-07-24 18:49:21              17                   0  5.884615
#
#    Potentiometer_Datar2  Potentiometer_Data2  Potentiometer_Data3  \
# 0              0.000000                    0                    0
# 1              1.414214                    4                    8
# 2              1.000000                    1                    1
# 3              1.000000                    1                    1
# 4              0.000000                    0                    0
#
#    Potentiometer_Data4  Potentiometer_Data5  Potentiometer_Data6
# 0                    0                    0                    0
# ...

# %%
X = filtered_data[['Potentiometer_Data','Potentiometer_Datar2']]
y = filtered_data['Degree']
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
print(y_pred)
# Out:
# [-11.97459428   5.61557993   0.51639357   0.51639357 -11.97459428
#    0.51639357   0.51639357 -11.97459428   0.51639357   0.51639357
#  -11.97459428   5.61557993 -11.97459428 -11.97459428   0.51639357
#    0.51639357 -11.97459428   0.51639357 -11.97459428 -11.97459428
#    0.51639357   0.51639357 -11.97459428 -11.97459428   0.51639357
#    0.51639357   0.51639357 -11.97459428   0.51639357   0.51639357
#    0.51639357   0.51639357   0.51639357 -11.97459428   0.51639357
#  -11.97459428   0.51639357   0.51639357 -11.97459428   0.51639357
#    0.51639357   0.51639357   5.61557993 -11.97459428   0.51639357
#  -11.97459428   0.51639357 -11.97459428 -11.97459428   0.51639357
#    0.51639357   0.51639357   0.51639357   0.51639357 -11.97459428
#  -11.97459428 -11.97459428 -11.97459428   5.61557993   0.51639357
#  -11.97459428 -11.97459428   0.51639357   0.51639357 -11.97459428
#    0.51639357 -11.97459428 -11.97459428 -11.97459428 -11.97459428
# ...

# %%
# Plot real data
plt.scatter(X['Potentiometer_Data'], y, color='blue', label='Real data')

# Plot polynomial fit
plt.plot(np.array(X['Potentiometer_Data']), y_pred, color='red', linestyle='--', label='Quadratic fit')

# Add labels and title
plt.xlabel('Feature')
plt.ylabel('Target')
plt.title('Quadratic Regression')
plt.legend()

# Show plot
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Calculate regression metrics
mse = mean_squared_error(y, y_pred)
mae = mean_absolute_error(y, y_pred)
r2 = r2_score(y, y_pred)

# Print the regression metrics
print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-squared (R2): {r2}")
# Out:
# Mean Squared Error (MSE): 29.907443386352977
# Mean Absolute Error (MAE): 4.035748476803001
# R-squared (R2): 0.9946959583584892

# %%
X = filtered_data[['Potentiometer_Data','Potentiometer_Data2','Potentiometer_Datar2']]
y = filtered_data['Degree']
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)
# Plot real data
plt.scatter(X['Potentiometer_Data'], y, color='blue', label='Real data')

# Plot polynomial fit
plt.plot(np.array(X['Potentiometer_Data']), y_pred, color='red', linestyle='--', label='Quadratic fit')

# Add labels and title
plt.xlabel('Feature')
plt.ylabel('Target')
plt.title('Quadratic Regression')
plt.legend()

# Show plot
plt.show()
# Calculate regression metrics
mse = mean_squared_error(y, y_pred)
mae = mean_absolute_error(y, y_pred)
r2 = r2_score(y, y_pred)

# Print the regression metrics
print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-squared (R2): {r2}")
# Out:
# Mean Squared Error (MSE): 24.049318504656586
# Mean Absolute Error (MAE): 3.9487237226941345
# R-squared (R2): 0.9957348882968425

# %%
X = filtered_data[['Potentiometer_Data','Potentiometer_Data2','Potentiometer_Datar2','Potentiometer_Data3']]
y = filtered_data['Degree']
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)
# Plot real data
plt.scatter(X['Potentiometer_Data'], y, color='blue', label='Real data')

# Plot polynomial fit
plt.plot(np.array(X['Potentiometer_Data']), y_pred, color='red', linestyle='--', label='Quadratic fit')

# Add labels and title
plt.xlabel('Feature')
plt.ylabel('Target')
plt.title('Quadratic Regression')
plt.legend()

# Show plot
plt.show()
# Calculate regression metrics
mse = mean_squared_error(y, y_pred)
mae = mean_absolute_error(y, y_pred)
r2 = r2_score(y, y_pred)

# Print the regression metrics
print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-squared (R2): {r2}")
# Out:
# Mean Squared Error (MSE): 17.319369537520835
# Mean Absolute Error (MAE): 3.252946430357948
# R-squared (R2): 0.9969284349703512

# %%
X = filtered_data[['Potentiometer_Data','Potentiometer_Data2','Potentiometer_Datar2','Potentiometer_Data3','Potentiometer_Data4']]
y = filtered_data['Degree']
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)
# Plot real data
plt.scatter(X['Potentiometer_Data'], y, color='blue', label='Real data')

# Plot polynomial fit
plt.plot(np.array(X['Potentiometer_Data']), y_pred, color='red', linestyle='--', label='Quadratic fit')

# Add labels and title
plt.xlabel('Feature')
plt.ylabel('Target')
plt.title('Quadratic Regression')
plt.legend()

# Show plot
plt.show()
# Calculate regression metrics
mse = mean_squared_error(y, y_pred)
mae = mean_absolute_error(y, y_pred)
r2 = r2_score(y, y_pred)

# Print the regression metrics
print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-squared (R2): {r2}")
# Out:
# Mean Squared Error (MSE): 14.679925518913954
# Mean Absolute Error (MAE): 2.9540487629944847
# R-squared (R2): 0.9973965365330383

# %%
X = filtered_data[['Potentiometer_Data','Potentiometer_Data2','Potentiometer_Datar2','Potentiometer_Data3','Potentiometer_Data4','Potentiometer_Data5']]
y = filtered_data['Degree']
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)
# Plot real data
plt.scatter(X['Potentiometer_Data'], y, color='blue', label='Real data')

# Plot polynomial fit
plt.plot(np.array(X['Potentiometer_Data']), y_pred, color='red', linestyle='--', label='Quadratic fit')

# Add labels and title
plt.xlabel('Feature')
plt.ylabel('Target')
plt.title('Quadratic Regression')
plt.legend()

# Show plot
plt.show()
# Calculate regression metrics
mse = mean_squared_error(y, y_pred)
mae = mean_absolute_error(y, y_pred)
r2 = r2_score(y, y_pred)

# Print the regression metrics
print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-squared (R2): {r2}")
# Out:
# Mean Squared Error (MSE): 13.103588236011015
# Mean Absolute Error (MAE): 2.68135970922491
# R-squared (R2): 0.9976760976603996

# %%
X = filtered_data[['Potentiometer_Data','Potentiometer_Data2','Potentiometer_Datar2','Potentiometer_Data3','Potentiometer_Data4','Potentiometer_Data5','Potentiometer_Data6']]
y = filtered_data['Degree']
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)
# Plot real data
plt.scatter(X['Potentiometer_Data'], y, color='blue', label='Real data')

# Plot polynomial fit
plt.plot(np.array(X['Potentiometer_Data']), y_pred, color='red', linestyle='--', label='Quadratic fit')

# Add labels and title
plt.xlabel('Feature')
plt.ylabel('Target')
plt.title('Quadratic Regression')
plt.legend()

# Show plot
plt.show()
# Calculate regression metrics
mse = mean_squared_error(y, y_pred)
mae = mean_absolute_error(y, y_pred)
r2 = r2_score(y, y_pred)

# Print the regression metrics
print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-squared (R2): {r2}")
# Out:
# Mean Squared Error (MSE): 181.89951114512715
# Mean Absolute Error (MAE): 10.813089233269537
# R-squared (R2): 0.9677403859226414

# %%
# again taking another feature that is cube root, log and exponential
filtered_data['Potentiometer_Datar3'] = np.cbrt(filtered_data['Potentiometer_Data'])
# filtered_data['Potentiometer_Datalog'] = np.log(filtered_data['Potentiometer_Data']) # these data gives very high values
# filtered_data['Potentiometer_Datalog10'] = np.log10(filtered_data['Potentiometer_Data'])
# filtered_data['Potentiometer_Datalog2'] = np.log2(filtered_data['Potentiometer_Data'])
filtered_data['Potentiometer_Datalog1p'] = np.log1p(filtered_data['Potentiometer_Data'])
# filtered_data['Potentiometer_Dataexp'] = np.exp(filtered_data['Potentiometer_Data'])
# Out:
# /tmp/ipykernel_24188/1966078425.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['Potentiometer_Datar3'] = np.cbrt(filtered_data['Potentiometer_Data'])
# /home/pawan/.local/lib/python3.10/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /tmp/ipykernel_24188/1966078425.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
X = filtered_data[['Potentiometer_Data','Potentiometer_Datar3','Potentiometer_Datar2','Potentiometer_Data2']]
y = filtered_data['Degree']
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)
# Plot real data
plt.scatter(X['Potentiometer_Data'], y, color='blue', label='Real data')

# Plot polynomial fit
plt.plot(np.array(X['Potentiometer_Data']), y_pred, color='red', linestyle='--', label='Quadratic fit')

# Add labels and title
plt.xlabel('Feature')
plt.ylabel('Target')
plt.title('Quadratic Regression')
plt.legend()

# Show plot
plt.show()
# Calculate regression metrics
mse = mean_squared_error(y, y_pred)
mae = mean_absolute_error(y, y_pred)
r2 = r2_score(y, y_pred)

# Print the regression metrics
print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-squared (R2): {r2}")
# Out:
# Mean Squared Error (MSE): 11.096066099814635
# Mean Absolute Error (MAE): 2.4645854107947884
# R-squared (R2): 0.9980321287951605

# %%
X = filtered_data[['Potentiometer_Data','Potentiometer_Datalog1p','Potentiometer_Datar2','Potentiometer_Datar3','Potentiometer_Data2']]
y = filtered_data['Degree']
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)
# Plot real data
plt.scatter(X['Potentiometer_Data'], y, color='blue', label='Real data')

# Plot polynomial fit
plt.plot(np.array(X['Potentiometer_Data']), y_pred, color='red', linestyle='--', label='Quadratic fit')

# Add labels and title
plt.xlabel('Feature')
plt.ylabel('Target')
plt.title('Quadratic Regression')
plt.legend()

# Show plot
plt.show()
# Calculate regression metrics
mse = mean_squared_error(y, y_pred)
mae = mean_absolute_error(y, y_pred)
r2 = r2_score(y, y_pred)

# Print the regression metrics
print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-squared (R2): {r2}")
# Out:
# Mean Squared Error (MSE): 10.499622515442876
# Mean Absolute Error (MAE): 2.3071771669046064
# R-squared (R2): 0.9981379071984647

# %%
# Get the coefficients and intercept
coefficients = model.coef_
intercept = model.intercept_

print(f"Model equation: y = ({coefficients[0]}) * X + ({coefficients[1]}) * log(1+X) + ({coefficients[2]}) * X^(1/2) + ({coefficients[3]}) * X^(1/3) + ({coefficients[4]}) * X^(2) + {intercept}")
# Out:
# Model equation: y = (-0.4371695184050939) * X + (-8.032545288775253) * log(1+X) + (28.389727126038505) * X^(1/2) + (-23.35291734822751) * X^(1/3) + (8.189276610082175e-05) * X^(2) + 5.587222922848468

# %% [markdown]
# **Hence we got our equation which has least error and high accuracy. Lets test this model for another data having 5 rev/min**

# %%
#extract the data for the motor position we have made our model based on
filter = (df_s_5_2['Motor_Position']>=0) & (df_s_5_2['Motor_Position']<=750)
test_data = df_s_5_2[filter]
print(test_data.head())
# Out:
#              Timestamp  Motor_Position  Potentiometer_Data
# 0  2024-07-24 18:46:58               0                   0
# 1  2024-07-24 18:46:58               0                   0
# 2  2024-07-24 18:46:58               6                   2
# 3  2024-07-24 18:46:58              23                   4
# 4  2024-07-24 18:46:58              33                   5

# %%
#extracting the features required for our model and extracting the targets
test_data['Degree'] = (test_data['Motor_Position']/1040)*360
test_data['Potentiometer_Datar3'] = np.cbrt(test_data['Potentiometer_Data'])
test_data['Potentiometer_Datalog1p'] = np.log1p(test_data['Potentiometer_Data'])
test_data['Potentiometer_Datar2'] = np.sqrt(test_data['Potentiometer_Data'])
test_data['Potentiometer_Data2'] = test_data['Potentiometer_Data']**2
# Out:
# /tmp/ipykernel_24188/2646182024.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['Degree'] = (test_data['Motor_Position']/1040)*360
# /tmp/ipykernel_24188/2646182024.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['Potentiometer_Datar3'] = np.cbrt(test_data['Potentiometer_Data'])
# /tmp/ipykernel_24188/2646182024.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
X_test = test_data[['Potentiometer_Data','Potentiometer_Datalog1p','Potentiometer_Datar2','Potentiometer_Datar3','Potentiometer_Data2']]
y_test = test_data['Degree']

y_pred = model.predict(X_test)
# Plot real data
plt.scatter(X_test['Potentiometer_Data'], y_test, color='blue', label='Real data')

# Plot polynomial fit
plt.plot(np.array(X_test['Potentiometer_Data']), y_pred, color='red', linestyle='--', label='Quadratic fit')

# Add labels and title
plt.xlabel('Feature')
plt.ylabel('Target')
plt.title('Quadratic Regression')
plt.legend()

# Show plot
plt.show()
# Calculate regression metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print the regression metrics
print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-squared (R2): {r2}")
# Out:
# Mean Squared Error (MSE): 9.10430074344983
# Mean Absolute Error (MAE): 2.285413774776993
# R-squared (R2): 0.9983576258566157

# %% [markdown]
# **Hence our Model is perfectly good.**
